# %%
"""
Author : Byunghyun Ban
Date : 2020.07.17.
"""
import random

import time
try:
    from matplotlib import pyplot as plt
except ModuleNotFoundError:
    import pip
    pip.main(['install', 'matplotlib'])
    try:
        from matplotlib import pyplot as plt
    except ModuleNotFoundError:
        time.sleep(2)
        from matplotlib import pyplot as plt

try:
    import numpy as np
except ModuleNotFoundError:
    import pip
    pip.main(['install', 'numpy'])
    try:
        import numpy as np
    except ModuleNotFoundError:
        time.sleep(2)
        import numpy as np


# 데이터를 떠먹여 줄 클래스를 제작합니다.
class DataReader():
    def __init__(self):
        self.label = ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]

        self.train_X, self.train_Y, self.test_X, self.test_Y = self.read_data()

        # 데이터 읽기가 완료되었습니다.
        # 읽어온 데이터의 정보를 출력합니다.
        print("\n\nData Read Done!")
        print("Training X Size : " + str(self.train_X.shape))
        print("Training Y Size : " + str(self.train_Y.shape))
        print("Test X Size : " + str(self.test_X.shape))
        print("Test Y Size : " + str(self.test_Y.shape) + '\n\n')

    def read_data(self):
        print("Reading Data...")
        file = open("data/iris.csv")
        data = []
        for line in file:
            splt = line.split(",")
            if len(splt) != 5:
              break
            feature_1 = float(splt[0].strip())
            feature_2 = float(splt[1].strip())
            feature_3 = float(splt[2].strip())
            feature_4 = float(splt[3].strip())
            label = self.label.index(splt[4].strip())
            data.append(((feature_1, feature_2, feature_3, feature_4), label))

        random.shuffle(data)

        X = []
        Y = []

        for el in data:
            X.append(el[0])
            Y.append(el[1])

        X = np.asarray(X)
        Y = np.asarray(Y)

        X = X / np.max(X, axis=0)

        train_X = X[:int(len(X)*0.8)]
        train_Y = Y[:int(len(Y)*0.8)]
        test_X = X[int(len(X)*0.8):]
        test_Y = Y[int(len(Y)*0.8):]

        return train_X, train_Y, test_X, test_Y


def draw_graph(history):
    train_history = history.history["loss"]
    validation_history = history.history["val_loss"]
    fig = plt.figure(figsize=(8, 8))
    plt.title("Loss History")
    plt.xlabel("EPOCH")
    plt.ylabel("LOSS Function")
    plt.plot(train_history, "red")
    plt.plot(validation_history, 'blue')
    fig.savefig("train_history.png")

    train_history = history.history["accuracy"]
    validation_history = history.history["val_accuracy"]
    fig = plt.figure(figsize=(8, 8))
    plt.title("Accuracy History")
    plt.xlabel("EPOCH")
    plt.ylabel("Accuracy")
    plt.plot(train_history, "red")
    plt.plot(validation_history, 'blue')
    fig.savefig("accuracy_history.png")

# %%
"""
Author : Byunghyun Ban
Date : 2020.07.24.
"""
from tensorflow import keras
import data_reader

# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 20  # 예제 기본값은 20입니다.

# 데이터를 읽어옵니다.
dr = data_reader.DataReader()

# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Dense(4),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(3, activation='softmax')
])

# 인공신경망을 컴파일합니다.
model.compile(optimizer="adam", metrics=["accuracy"],
              loss="sparse_categorical_crossentropy")

# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS, batch_size=5,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])

# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
# Out:
# Reading Data...
#
#
# Data Read Done!
# Training X Size : (120, 4)
# Training Y Size : (120,)
# Test X Size : (30, 4)
# Test Y Size : (30,)
#
#
#
#
# ************ TRAINING START ************
# Epoch 1/20
# 24/24 [==============================] - 1s 13ms/step - loss: 1.0331 - accuracy: 0.5167 - val_loss: 1.0291 - val_accuracy: 0.6667
# Epoch 2/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9676 - accuracy: 0.6250 - val_loss: 0.9630 - val_accuracy: 0.6667
# Epoch 3/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9278 - accuracy: 0.6500 - val_loss: 0.9042 - val_accuracy: 0.6667
# Epoch 4/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8597 - accuracy: 0.7167 - val_loss: 0.8500 - val_accuracy: 0.6667
# Epoch 5/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8055 - accuracy: 0.7000 - val_loss: 0.7888 - val_accuracy: 0.6667
# Epoch 6/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7259 - accuracy: 0.7083 - val_loss: 0.7254 - val_accuracy: 0.7000
# Epoch 7/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6860 - accuracy: 0.7250 - val_loss: 0.6677 - val_accuracy: 0.7333
# Epoch 8/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6351 - accuracy: 0.7583 - val_loss: 0.6138 - val_accuracy: 0.7667
# Epoch 9/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5670 - accuracy: 0.8500 - val_loss: 0.5633 - val_accuracy: 0.8333
# Epoch 10/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5453 - accuracy: 0.8167 - val_loss: 0.5197 - val_accuracy: 0.8333
# Epoch 11/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4998 - accuracy: 0.8417 - val_loss: 0.4813 - val_accuracy: 0.8333
# Epoch 12/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4605 - accuracy: 0.8833 - val_loss: 0.4463 - val_accuracy: 0.9667
# Epoch 13/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4484 - accuracy: 0.8917 - val_loss: 0.4175 - val_accuracy: 0.9333
# Epoch 14/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4298 - accuracy: 0.8833 - val_loss: 0.3899 - val_accuracy: 1.0000
# Epoch 15/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.9417 - val_loss: 0.3647 - val_accuracy: 1.0000
# Epoch 16/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3438 - accuracy: 0.9250 - val_loss: 0.3423 - val_accuracy: 0.9667
# Epoch 17/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3337 - accuracy: 0.9417 - val_loss: 0.3240 - val_accuracy: 1.0000
# Epoch 18/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3537 - accuracy: 0.9000 - val_loss: 0.3076 - val_accuracy: 1.0000
# Epoch 19/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2916 - accuracy: 0.9750 - val_loss: 0.2919 - val_accuracy: 1.0000
# Epoch 20/20
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3002 - accuracy: 0.9167 - val_loss: 0.2802 - val_accuracy: 0.9667

# %% [markdown]
# ## 결과
# - 120개의 데이터는 인공지능을 다룰때에 너무 적은 데이터임에도 불구하고 정확도가 잘나옴
# - 2가지를 생각해볼 수 있음
#     - iris 데이터셋이 쉬운 데이터셋이다.
#     - 뉴럴 네트워크가 성능이 좋았다
#
# - Accuracy : test value가 더 높은 구간이 유지되고 있는것으로 보아 데이터가 너무 적어 일반화까지 도달하지 못했음. but 뉴럴 네트워크의 성능이 좋아 어느정도 정답에 근접하게 되었다.
# - Loss : dropout을 사용했기에 overfitting이 거의 없다.
